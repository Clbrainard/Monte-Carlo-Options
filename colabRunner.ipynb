# %%
import os
import shutil

# 1. Force move to the base directory
# %cd /content

# 2. Kill any zombie folder that might be causing the 'dir exists' error
repo_name = "Monte-Carlo-Options"
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# 3. Clone fresh (USE YOUR ACTUAL URL HERE)
# !git clone https://github.com/Clbrainard/Monte-Carlo-Options.git

# 4. Move into the folder
# %cd {repo_name}

# 5. Check what's inside
# !ls
# Out:
# /content
# Cloning into 'Monte-Carlo-Options'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 23 (delta 6), reused 20 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 39.66 KiB | 665.00 KiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/Monte-Carlo-Options
# colabRunner.ipynb  monteCarloAlgorithm.py  regressionSchedule.py  tester.py
# gbm.py		   __pycache__		   TestData

# %%
from tester import Tester

paths = 100
samples = 10
stepsPerHour = 60
ITMonly = False
OTMonly = False

Tester.analyzeVariedPathCount([25,50,100,150,200,250],50,12,False,False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3556132279.py in <cell line: 0>()
#       7 OTMonly = False
#       8
# ----> 9 Tester.analyzeVariedPathCount([25,50,100,150,200,250],50,12,False,False)
#
# AttributeError: type object 'Tester' has no attribute 'analyzeVariedPathCount'
