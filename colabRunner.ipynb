# %%
import os
import shutil

# 1. Force move to the base directory
# %cd /content

# 2. Kill any zombie folder that might be causing the 'dir exists' error
repo_name = "Monte-Carlo-Options"
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# 3. Clone fresh (USE YOUR ACTUAL URL HERE)
# !git clone https://github.com/Clbrainard/Monte-Carlo-Options.git

# 4. Move into the folder
# %cd {repo_name}

# 5. Check what's inside
# !ls
# Out:
# /content
# Cloning into 'Monte-Carlo-Options'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 38 (delta 16), reused 28 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (38/38), 70.31 KiB | 1.13 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/Monte-Carlo-Options
# colabRunner.ipynb	plot.png	       tempCodeRunnerFile.py
# gbm.py			__pycache__	       TestData
# monteCarloAlgorithm.py	regressionSchedule.py  tester.py

# %%
from tester import Tester

paths = 100
samples = 10
stepsPerHour = 60
ITMonly = False
OTMonly = False

Tester.analyzeVariedPathCount([25,50,100,150,200,250],50,12,False,False)
# Out:
# 0     0.010049
# 1     0.970570
# 2     0.007751
# 3     1.000000
# 4     0.612075
# 5     1.000000
# 6     0.555451
# 7     0.649578
# 8     0.991455
# 9     0.008392
# 10    0.038798
# 11    0.036297
# 12    0.051028
# 13    1.000000
# 14    0.551897
# 15    0.972319
# 16    0.985611
# 17    0.331633
# 18    0.103732
# 19    0.659455
# 20    0.764110
# 21    0.012394
# 22    0.707063
# 23    0.577800
# 24    0.004269
# 25    0.349958
# 26    0.793864
# 27    0.025470
# 28    0.110114
# 29    0.647237
# 30    0.020570
# 31    0.002023
# 32    0.000512
# 33    0.923233
# 34    0.019392
# 35    0.008098
# 36    0.007013
# 37    0.001908
# 38    1.097017
# 39    0.989016
# 40    0.960055
# 41    0.831025
# 42    0.861482
# 43    0.173029
# 44    0.752080
# 45    0.239064
# 46    1.000000
# 47    0.570775
# 48    0.036402
# 49    0.603377
# Name: percentError, dtype: float64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3556132279.py in <cell line: 0>()
# ----> 1 from tester import Tester
#       2
#       3 paths = 100
#       4 samples = 10
#       5 stepsPerHour = 60
#
# /content/Monte-Carlo-Options/tester.py in <module>
#     152         pass
#     153
# --> 154 Tester.analyzeVariedPathCount([25,50,100,150,200,250],50,60,False,False)
#
# /content/Monte-Carlo-Options/tester.py in analyzeVariedPathCount(testPathCounts, samples, stepsPerHour, ITMonly, OTMonly)
#     119         results = dict.fromkeys(testPathCounts)
#     120         for paths in testPathCounts:
# --> 121             sampleResults, params = Tester.runTest(paths,365*24*stepsPerHour,0.04,samples,"FridayPutSpread_MSFT","put",ITMonly,OTMonly)
#     122             print(sampleResults["percentError"])
#     123             results[paths] = sampleResults
#
# /content/Monte-Carlo-Options/tester.py in runTest(paths, stepsPerYear, riskFreeRate, numSamples, dataSet, parity, ITMonly, OTMonly)
#      15         results = pd.DataFrame(columns=["prediction","target","error","percentError","moneyness","time"])
#      16         for row in samples.itertuples():
# ---> 17             prediction, target, error, moneyness, time = Tester.testRow(row,paths,stepsPerYear,riskFreeRate,parity)
#      18             results.loc[len(results)] = [prediction, target, error, error/target, moneyness, time]
#      19
#
# /content/Monte-Carlo-Options/tester.py in testRow(row, paths, stepsPerYear, riskFreeRate, parity)
#      29         T = row.minutesUntilExpiration / (365*24*60)
#      30         steps = int(T * stepsPerYear)
# ---> 31         prediction = MonteCarloAlgorithm.priceOption(row.stockPrice,T,steps,paths,riskFreeRate,row.impliedVolatility,row.strike,parity)
#      32         return prediction, row.optionPrice, abs(prediction - row.optionPrice), row.moneyness, T
#      33
#
# /content/Monte-Carlo-Options/monteCarloAlgorithm.py in priceOption(So, T, N, P, r, v, K, side)
#      25
#      26
# ---> 27         CF = MonteCarloAlgorithm.fillCashflowTable(S,C,R,P,N,intrinsic)
#      28         return MonteCarloAlgorithm.solvePriceFromCF(CF,R,P,N)
#      29
#
# /content/Monte-Carlo-Options/monteCarloAlgorithm.py in fillCashflowTable(S, C, R, P, N, intrinsic)
#      33         CF = C.copy()
#      34         for n in range(N-2, -1, -1):
# ---> 35             CF[:,n] = MonteCarloAlgorithm.inductiveStep(S,CF,R,P,n,intrinsic)
#      36         return CF
#      37
#
# /content/Monte-Carlo-Options/monteCarloAlgorithm.py in inductiveStep(S, CF, R, P, n, intrinsic)
#      61             return output
#      62
# ---> 63         a,b,c = MonteCarloAlgorithm.LSM(X,Y)
#      64
#      65         def EV(x):
#
# /content/Monte-Carlo-Options/monteCarloAlgorithm.py in LSM(X, Y)
#      86             b, c = np.polyfit(X, Y, deg=1)
#      87         else:
# ---> 88             a, b, c = np.polyfit(X, Y, deg=2)
#      89         return a,b,c
#      90
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_polynomial_impl.py in polyfit(x, y, deg, rcond, full, w, cov)
#     656     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     657     lhs /= scale
# --> 658     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     659     c = (c.T/scale).T  # broadcast scale coefficients
#     660
#
# /usr/local/lib/python3.12/dist-packages/numpy/linalg/_linalg.py in lstsq(a, b, rcond)
#    2504         b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
#    2505
# -> 2506     with errstate(call=_raise_linalgerror_lstsq, invalid='call',
#    2507                   over='ignore', divide='ignore', under='ignore'):
#    2508         x, resids, rank, s = gufunc(a, b, rcond, signature=signature)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_ufunc_config.py in __exit__(self, *exc_info)
#     425
#     426     def __exit__(self, *exc_info):
# --> 427         _extobj_contextvar.reset(self._token)
#     428
#     429     def __call__(self, func):
#
# KeyboardInterrupt:
