# %%
import os
import shutil

# 1. Force move to the base directory
# %cd /content

# 2. Kill any zombie folder that might be causing the 'dir exists' error
repo_name = "Monte-Carlo-Options"
if os.path.exists(repo_name):
    shutil.rmtree(repo_name)

# 3. Clone fresh (USE YOUR ACTUAL URL HERE)
# !git clone https://github.com/Clbrainard/Monte-Carlo-Options.git

# 4. Move into the folder
# %cd {repo_name}

# 5. Check what's inside
# !ls
# Out:
# /content
# Cloning into 'Monte-Carlo-Options'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 0), reused 15 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 12.99 KiB | 12.99 MiB/s, done.
# /content/Monte-Carlo-Options
# colabRunner.ipynb  monteCarloAlgorithm.py  regressionSchedule.py  tester.py
# gbm.py		   __pycache__		   TestData

# %%
from tester import Tester

paths = 100
samples = 10
stepsPerHour = 60
ITMonly = False
OTMonly = False

Tester.runAnalysis(paths,samples,stepsPerHour,ITMonly,OTMonly)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4108858806.py in <cell line: 0>()
#       7 OTMonly = False
#       8
# ----> 9 Tester.runAnalysis(paths,samples,stepsPerHour,ITMonly,OTMonly)
#
# AttributeError: type object 'Tester' has no attribute 'runAnalysis'
